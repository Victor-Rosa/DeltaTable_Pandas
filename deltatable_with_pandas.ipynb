# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
from deltalake import DeltaTable
from deltalake.writer import write_deltalake

# %% [markdown]
# ### Dataframe Pandas

# %%
df = pd.read_csv("./data/petlove_consumer.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  10000 non-null  object
#  1   created_at          10000 non-null  object
#  2   updated_at          10000 non-null  object
#  3   deleted_at          505 non-null    object
#  4   name_hash           10000 non-null  object
#  5   email_hash          10000 non-null  object
#  6   address_hash        10000 non-null  object
#  7   birth_date          10000 non-null  object
#  8   status              10000 non-null  object
#  9   version             10000 non-null  object
#  10  city                10000 non-null  object
#  11  state               10000 non-null  object
#  12  neighborhood        10000 non-null  object
#  13  last_date_purchase  10000 non-null  object
#  14  average_ticket      10000 non-null  float64
# ...

# %%
df.head()
# Out:
#                                      id         created_at         updated_at  \
# 0  8bf7960e-3b93-468b-856e-6c6c5b56f52b  08/15/17 07:05 AM  01/14/21 11:23 AM
# 1  a39535b5-4647-4680-b4f6-3aed57c1f1ff  12/31/19 09:53 PM  01/08/21 11:23 AM
# 2  dc067cd2-c021-42bd-8c0e-beb267280e66  03/07/19 11:46 PM  01/07/21 11:23 AM
# 3  b5e4caeb-3a9b-49ed-aa33-5acd06b162c1  07/21/18 10:17 AM  01/10/21 11:23 AM
# 4  d4ff61fc-f008-4e19-b8ae-bd70cfa3ae27  06/08/18 12:09 PM  01/18/21 11:23 AM
#
#   deleted_at                         name_hash  \
# 0        NaN  312d206168a318614897e8ccac43bff9
# 1        NaN  de448fcb47d0d6a873b2eef52b5ee595
# 2        NaN  cb09e447ddc38283373d56bb46498e6a
# 3        NaN  52593437a405b11b3557170680ef80c8
# 4        NaN  dbda4b778a966c21904238ed2d2005db
#
#                          email_hash                      address_hash  \
# 0  83eb3aed9a44377df80ce876dce92c9a  8b4bfaa0cbc41a16f46da15ddcd6a907
# ...

# %% [markdown]
# ### Dataframe DeltaTable

# %% [markdown]
# ### Transformando o arquivo CSV em Delta

# %%
write_deltalake('./data/deltalake/petlove_consumer', df,
                description="Um teste para transformar o csv da petlove em um formato Delta Table",
                partition_by=['state'])

# %% [markdown]
# ### Lendo o Arquivo em formato Delta

# %%
dt = DeltaTable("./data/deltalake/petlove_consumer").to_pandas()

# %%
dt
# Out:
#                                         id         created_at  \
# 0     d4ff61fc-f008-4e19-b8ae-bd70cfa3ae27  06/08/18 12:09 PM
# 1     48c5e611-835d-4aad-9a42-114dfd93c01b  07/17/16 10:30 AM
# 2     0bd41d8e-a514-40b2-95f2-7c258e595528  07/28/20 04:55 PM
# 3     ec24d488-7778-4207-8f2d-10eca4c49944  04/01/16 01:08 PM
# 4     35607577-327c-4c23-be32-5a33317a34fb  09/16/17 10:38 PM
# ...                                    ...                ...
# 9995  b53f4838-c8f7-4262-b6f2-3a4a10de64e0  05/12/17 04:48 PM
# 9996  baae8960-6a11-48c0-8282-ac0fdddc1e9d  03/28/18 11:53 PM
# 9997  6653a1a2-5ef8-482f-9105-530ce7c57e98  06/21/17 11:42 PM
# 9998  f55ce7c3-fa5f-43b4-9d09-61ceb06f4ba1  04/14/17 04:53 AM
# 9999  d82c35e5-967a-4136-8355-e1b2be31e1ca  02/11/21 08:04 PM
#
#              updated_at deleted_at                         name_hash  \
# 0     01/18/21 11:23 AM       None  dbda4b778a966c21904238ed2d2005db
# 1     01/11/21 11:23 AM       None  480c8dbeaf38e36b7eaa4914ff12b4d6
# ...
